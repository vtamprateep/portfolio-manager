# %%
import scipy.stats as stats
import pandas as pd
import psycopg2
import numpy as np
import math
import json
import os
import backtrader as bt
import datetime
import matplotlib

# %%
# Connect to db
conn = psycopg2.connect('dbname=securities user=postgres')
cur = conn.cursor()

# %%
# Get all price data
query_all = '''
    SELECT *
    FROM prices
    ORDER BY symbol ASC, datetime ASC
'''
cur.execute(query_all)
data = cur.fetchall()
price_df = pd.DataFrame(data, columns = ['symbol', 'date', 'open', 'high', 'low', 'close'])
price_df.loc[:, 'date'] = pd.to_datetime(price_df['date'])
price_df = price_df.set_index('date')

# Get list of all unique tickers
ticker_list = price_df.symbol.unique()

# %%
class SMAIndicator(bt.Indicator):
    lines = ('sma',)
    params = {
        'long_ma': None,
        'short_ma': None,
    }
    
    def __init__(self):
        self.addminperiod(max(self.params.long_ma, self.params.short_ma))
        self.long_period = max(self.params.long_ma, self.params.short_ma)
        self.short_period = min(self.params.long_ma, self.params.short_ma)
    
    def next(self):
        sma_long = np.mean(self.data.get(size = self.long_period))
        sma_short = np.mean(self.data.get(size = self.short_period))
        self.lines.sma[0] = sma_short - sma_long

# %%
class TestStrategy(bt.Strategy):
    
    params = {
        'trade_freq': None,
        'feed_name': None,
    }
    
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))
        
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.sma = SMAIndicator(long_ma = 30, short_ma = 10)
        self.days = 0
        
        self.inds = dict()
        for i, d in enumerate(self.datas):
            self.inds[d] = dict()
            self.inds[d]['sma'] = self.sma
        
        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, PRICE: %.2f, Cost: %.2f, Comm %.2f' % (
                        order.executed.price,
                        order.executed.value,
                        order.executed.comm,
                    )
                )
            else:
                self.log(
                    'SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' % (
                        order.executed.price,
                        order.executed.value,
                        order.executed.comm,
                    )
                )
            self.bar_executed = len(self)
            
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None
        
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        self.log(
            'OPERATION PROFIT, GROSS %.2f, NET %.2f' % (
                trade.pnl,
                trade.pnlcomm,
            )
        )
        
    def next(self):
        self.days += 1
        
        if self.days > self.params.trade_freq - 1:
            self.days = 0
            for i, d in enumerate(self.datas):
                dt, dn = self.datetime.date(), d._name
                if not self.order:
                    if self.inds[d]['sma'][0] > 0:
                        self.log('BUY CREATE, %.2f' % d.close[0])
                        self.order = self.buy(data = d, size = 2)
                    else:
                        self.log('SELL CREATE, %.2f' % d.close[0])
                        self.order = self.sell(data = d, size = 2)
                print(self.getposition(d))
        
        '''
        if self.days > self.params.trade_freq - 1:
            self.days = 0
            if not self.position:
                if self.sma > 0:
                    self.log('BUY CREATE, %.2f' % self.dataclose[0])
                    self.order = self.buy()
            elif self.sma < 0:
                self.log('SELL CREATE, %.2f' % self.dataclose[0])
                self.order = self.sell()
        '''

# %%
cerebro = bt.Cerebro()

# Load all feeds into Cerebro
for ticker in ['SPY', 'IWO']:
    ticker_df = price_df[price_df['symbol'] == ticker]
    cerebro.adddata(bt.feeds.PandasData(dataname = ticker_df, datetime = -1))

cerebro.addstrategy(TestStrategy, trade_freq = 10, feed_name = ticker_list)
# Out:
# 0

# %%
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
cerebro.run()
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 10000.00
# 2019-10-22, BUY CREATE, 299.01
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2019-10-23, BUY EXECUTED, PRICE: 298.73, Cost: 597.46, Comm 0.00
# 2019-11-05, BUY CREATE, 307.03
# --- Position Begin
# - Size: 2
# - Price: 298.73
# - Price orig: 0.0
# - Closed: 0
# - Opened: 2
# - Adjbase: 307.03
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2019-11-06, BUY EXECUTED, PRICE: 307.03, Cost: 614.06, Comm 0.00
# 2019-11-19, BUY CREATE, 311.93
# --- Position Begin
# - Size: 4
# - Price: 302.88
# - Price orig: 298.73
# - Closed: 0
# - Opened: 2
# - Adjbase: 311.93
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2019-11-20, BUY EXECUTED, PRICE: 311.28, Cost: 622.56, Comm 0.00
# 2019-12-04, BUY CREATE, 311.46
# --- Position Begin
# - Size: 6
# - Price: 305.68
# - Price orig: 302.88
# - Closed: 0
# - Opened: 2
# - Adjbase: 311.46
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2019-12-05, BUY EXECUTED, PRICE: 312.23, Cost: 624.46, Comm 0.00
# 2019-12-18, BUY CREATE, 319.59
# --- Position Begin
# - Size: 8
# - Price: 307.3175
# - Price orig: 305.68
# - Closed: 0
# - Opened: 2
# - Adjbase: 319.59
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2019-12-19, BUY EXECUTED, PRICE: 319.80, Cost: 639.60, Comm 0.00
# 2020-01-03, BUY CREATE, 322.41
# --- Position Begin
# - Size: 10
# - Price: 309.81399999999996
# - Price orig: 307.3175
# - Closed: 0
# - Opened: 2
# - Adjbase: 322.41
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-01-06, BUY EXECUTED, PRICE: 320.49, Cost: 640.98, Comm 0.00
# 2020-01-17, BUY CREATE, 331.95
# --- Position Begin
# - Size: 12
# - Price: 311.5933333333333
# - Price orig: 309.81399999999996
# - Closed: 0
# - Opened: 2
# - Adjbase: 331.95
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-01-21, BUY EXECUTED, PRICE: 330.90, Cost: 661.80, Comm 0.00
# 2020-02-03, BUY CREATE, 324.12
# --- Position Begin
# - Size: 14
# - Price: 314.3514285714286
# - Price orig: 311.5933333333333
# - Closed: 0
# - Opened: 2
# - Adjbase: 324.12
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-02-04, BUY EXECUTED, PRICE: 328.07, Cost: 656.14, Comm 0.00
# 2020-02-18, BUY CREATE, 336.73
# --- Position Begin
# - Size: 16
# - Price: 316.06625
# - Price orig: 314.3514285714286
# - Closed: 0
# - Opened: 2
# - Adjbase: 336.73
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-02-19, BUY EXECUTED, PRICE: 337.79, Cost: 675.58, Comm 0.00
# 2020-03-03, SELL CREATE, 300.24
# --- Position Begin
# - Size: 18
# - Price: 318.48
# - Price orig: 316.06625
# - Closed: 0
# - Opened: 2
# - Adjbase: 300.24
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-03-04, SELL EXECUTED, Price: 306.12, Cost: 636.96, Comm 0.00
# 2020-03-17, SELL CREATE, 252.80
# --- Position Begin
# - Size: 16
# - Price: 318.48
# - Price orig: 318.48
# - Closed: -2
# - Opened: 0
# - Adjbase: 252.8
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-03-18, SELL EXECUTED, Price: 236.25, Cost: 636.96, Comm 0.00
# 2020-03-31, SELL CREATE, 257.75
# --- Position Begin
# - Size: 14
# - Price: 318.48
# - Price orig: 318.48
# - Closed: -2
# - Opened: 0
# - Adjbase: 257.75
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-04-01, SELL EXECUTED, Price: 247.98, Cost: 636.96, Comm 0.00
# 2020-04-15, BUY CREATE, 277.76
# --- Position Begin
# - Size: 12
# - Price: 318.48
# - Price orig: 318.48
# - Closed: -2
# - Opened: 0
# - Adjbase: 277.76
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-04-16, BUY EXECUTED, PRICE: 279.15, Cost: 558.30, Comm 0.00
# 2020-04-29, BUY CREATE, 293.21
# --- Position Begin
# - Size: 14
# - Price: 312.8614285714286
# - Price orig: 318.48
# - Closed: 0
# - Opened: 2
# - Adjbase: 293.21
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-04-30, BUY EXECUTED, PRICE: 291.71, Cost: 583.42, Comm 0.00
# 2020-05-13, BUY CREATE, 281.60
# --- Position Begin
# - Size: 16
# - Price: 310.21750000000003
# - Price orig: 312.8614285714286
# - Closed: 0
# - Opened: 2
# - Adjbase: 281.6
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-05-14, BUY EXECUTED, PRICE: 278.95, Cost: 557.90, Comm 0.00
# 2020-05-28, BUY CREATE, 302.97
# --- Position Begin
# - Size: 18
# - Price: 306.74333333333334
# - Price orig: 310.21750000000003
# - Closed: 0
# - Opened: 2
# - Adjbase: 302.97
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-05-29, BUY EXECUTED, PRICE: 302.46, Cost: 604.92, Comm 0.00
# 2020-06-11, BUY CREATE, 300.61
# --- Position Begin
# - Size: 20
# - Price: 306.315
# - Price orig: 306.74333333333334
# - Closed: 0
# - Opened: 2
# - Adjbase: 300.61
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-06-12, BUY EXECUTED, PRICE: 308.24, Cost: 616.48, Comm 0.00
# 2020-06-25, BUY CREATE, 307.35
# --- Position Begin
# - Size: 22
# - Price: 306.49
# - Price orig: 306.315
# - Closed: 0
# - Opened: 2
# - Adjbase: 307.35
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-06-26, BUY EXECUTED, PRICE: 306.16, Cost: 612.32, Comm 0.00
# 2020-07-10, BUY CREATE, 317.59
# --- Position Begin
# - Size: 24
# - Price: 306.46250000000003
# - Price orig: 306.49
# - Closed: 0
# - Opened: 2
# - Adjbase: 317.59
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-07-13, BUY EXECUTED, PRICE: 320.13, Cost: 640.26, Comm 0.00
# 2020-07-24, BUY CREATE, 320.88
# --- Position Begin
# - Size: 26
# - Price: 307.5138461538462
# - Price orig: 306.46250000000003
# - Closed: 0
# - Opened: 2
# - Adjbase: 320.88
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-07-27, BUY EXECUTED, PRICE: 321.63, Cost: 643.26, Comm 0.00
# 2020-08-07, BUY CREATE, 334.57
# --- Position Begin
# - Size: 28
# - Price: 308.5221428571429
# - Price orig: 307.5138461538462
# - Closed: 0
# - Opened: 2
# - Adjbase: 334.57
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-08-10, BUY EXECUTED, PRICE: 335.06, Cost: 670.12, Comm 0.00
# 2020-08-21, BUY CREATE, 339.48
# --- Position Begin
# - Size: 30
# - Price: 310.2913333333334
# - Price orig: 308.5221428571429
# - Closed: 0
# - Opened: 2
# - Adjbase: 339.48
# --- Position End
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# 2020-08-24, Order Canceled/Margin/Rejected
# Final Portfolio Value: 10878.48

# %%
price_df[price_df['symbol'] == 'VTV'].head()
# Out:
#       symbol        date    open      high       low   close
# 52545    VTV  2019-08-28  105.95  107.1626  105.8103  107.11
# 52546    VTV  2019-08-29  108.03  108.4800  107.6000  108.24
# 52547    VTV  2019-08-30  108.86  109.0800  108.2598  108.52
# 52548    VTV  2019-09-03  107.87  108.2000  107.2800  108.12
# 52549    VTV  2019-09-04  108.97  109.2300  108.7500  109.17

# %%
price_df.symbol.unique()
# Out:
# array(['AAXJ', 'ACWI', 'ACWV', 'AGG', 'ASHR', 'ASHS', 'BBEU', 'BBJP',
#        'BBSA', 'BBUS', 'BIL', 'BKLN', 'BLV', 'BND', 'BNDW', 'BNDX',
#        'BSCP', 'BSCR', 'BSCS', 'BSV', 'BWX', 'BWZ', 'CNYA', 'CORP',
#        'CRBN', 'DEM', 'DES', 'DON', 'DSI', 'DVY', 'DWX', 'DXJS', 'EBND',
#        'EDV', 'EEM', 'EEMV', 'EFA', 'EFV', 'EMB', 'EMLC', 'EQAL', 'EWJ',
#        'EZU', 'FBND', 'FCOR', 'FDLO', 'FLOT', 'FLTB', 'FNDA', 'FNDB',
#        'FNDC', 'FNDF', 'FNDX', 'FTC', 'GEM', 'GMF', 'GOVT', 'GVAL', 'GVI',
#        'GWX', 'HYD', 'HYG', 'HYLD', 'IAF', 'IAGG', 'ICSH', 'IEF', 'IEFA',
#        'IEI', 'IEMG', 'IEUR', 'IEV', 'IGOV', 'IGSB', 'IJH', 'IJJ', 'IJK',
#        'IJR', 'IJS', 'IJT', 'ILTB', 'ISHG', 'ISTB', 'ITOT', 'IUSB',
#        'IUSV', 'IVE', 'IVOG', 'IVOO', 'IVV', 'IWB', 'IWC', 'IWD', 'IWM',
#        'IWN', 'IWO', 'IWP', 'IWR', 'IWS', 'IWV', 'IXUS', 'IYY', 'JDIV',
#        'JKH', 'JMIN', 'JMOM', 'JMST', 'JNK', 'JPEM', 'JPGB', 'JPHY',
#        'JPIN', 'JPMB', 'JPME', 'JPSE', 'JPST', 'JPUS', 'JQUA', 'JVAL',
#        'LQD', 'MDY', 'MDYG', 'MDYV', 'MFDX', 'MFEM', 'MFUS', 'MIDD',
#        'MINT', 'MUB', 'PCY', 'PFF', 'PGX', 'PIE', 'PLW', 'PXF', 'QUAL',
#        'QUS', 'RESE', 'RPG', 'RSP', 'SCHA', 'SCHB', 'SCHE', 'SCHF',
#        'SCHK', 'SCHM', 'SCHO', 'SCHP', 'SCHR', 'SCHV', 'SCHX', 'SCHZ',
#        'SCZ', 'SDY', 'SHM', 'SHV', 'SHY', 'SHYD', 'SHYG', 'SLQD', 'SLYG',
#        'SLYV', 'SPDW', 'SPIB', 'SPLG', 'SPLV', 'SPSM', 'SPTL', 'SPTM',
#        'SPTS', 'SPY', 'SPYV', 'STIP', 'SUB', 'TIP', 'TLH', 'TLT', 'TOTL',
#        'URTH', 'USHY', 'USIG', 'USMV', 'VB', 'VBK', 'VBR', 'VEA', 'VEU',
#        'VFLQ', 'VFMF', 'VFMO', 'VFQY', 'VFVA', 'VGIT', 'VGK', 'VGLT',
#        'VGSH', 'VIG', 'VIOO', 'VO', 'VOE', 'VOO', 'VOOV', 'VOT', 'VPL',
#        'VT', 'VTI', 'VTIP', 'VTV', 'VTWO', 'VV', 'VWO', 'VXF', 'VXUS',
#        'VYM', 'WDIV', 'ZROZ'], dtype=object)
